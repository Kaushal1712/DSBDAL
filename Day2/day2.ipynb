# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("Demo.xlsx")

# %%
df.head()
# Out:
#    Roll no            Name of Student  \
# 0        1          RAVAL MEET MAHESH
# 1        2      HUMBE BHAKTI RAJENDRA
# 2        3  MARATHE SANSKRUTI JAGDISH
# 3        4      THAKARE MRUNALI VINOD
# 4        5    BHONGALE OMKAR MADHUKAR
#
#    Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 0                                         1131        NaN        29.0
# 1                                         1107  79.071429        29.0
# 2                                          995  71.071429        27.0
# 3                                         1077  76.928571        28.0
# 4                                         1064  76.000000        28.0
#
#          %.1  50% maks of Previous Year SPPU Result  50% Marks of Unit Test 1  \
# 0  96.666667                                   44.0                        41
# 1  96.666667                                   42.0                        41
# ...

# %%
df.shape
# Out:
# (74, 10)

# %%
df.columns
# Out:
# Index(['Roll no', 'Name of Student',
#        'Previous Year SPPU Total Marks out of  1400', '%', 'UT 1 Marks', '%.1',
#        '50% maks of Previous Year SPPU Result', '50% Marks of Unit Test 1',
#        'Total 100%', 'Gender '],
#       dtype='object')

# %%
df.dtypes
# Out:
# Roll no                                          int64
# Name of Student                                 object
# Previous Year SPPU Total Marks out of  1400      int64
# %                                              float64
# UT 1 Marks                                     float64
# %.1                                            float64
# 50% maks of Previous Year SPPU Result          float64
# 50% Marks of Unit Test 1                         int64
# Total 100%                                     float64
# Gender                                          object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Roll no                                        0
# Name of Student                                0
# Previous Year SPPU Total Marks out of  1400    0
# %                                              2
# UT 1 Marks                                     2
# %.1                                            3
# 50% maks of Previous Year SPPU Result          1
# 50% Marks of Unit Test 1                       0
# Total 100%                                     0
# Gender                                         0
# dtype: int64

# %%
avg=df['%'].mean()

# %%
df['%'].fillna(avg,inplace=True)
# Out:
# /var/folders/q5/sxf7pxfx325bnp0p8jl4nyt80000gn/T/ipykernel_1847/4150232176.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['%'].fillna(avg,inplace=True)

# %%
df
# Out:
#     Roll no            Name of Student  \
# 0         1          RAVAL MEET MAHESH
# 1         2      HUMBE BHAKTI RAJENDRA
# 2         3  MARATHE SANSKRUTI JAGDISH
# 3         4      THAKARE MRUNALI VINOD
# 4         5    BHONGALE OMKAR MADHUKAR
# ..      ...                        ...
# 69       70      KUNWAR ABHIJEET SINGH
# 70       71             TUPE OM KISHOR
# 71       72       DARWEY RUDRA GUNWANT
# 72       73       JAGTAP HARISH YUVRAJ
# 73       74               ASHUTOSH RAJ
#
#     Previous Year SPPU Total Marks out of  1400          %  UT 1 Marks  \
# 0                                          1131  68.197421        29.0
# 1                                          1107  79.071429        29.0
# 2                                           995  71.071429        27.0
# 3                                          1077  76.928571        28.0
# 4                                          1064  76.000000        28.0
# ...

# %%
df.isnull().sum()
# Out:
# Roll no                                        0
# Name of Student                                0
# Previous Year SPPU Total Marks out of  1400    0
# %                                              0
# UT 1 Marks                                     2
# %.1                                            3
# 50% maks of Previous Year SPPU Result          1
# 50% Marks of Unit Test 1                       0
# Total 100%                                     0
# Gender                                         0
# dtype: int64
